# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **List Library**

# %%
# Importing library
import numpy as np
import pandas as pd

# BeautifulSoup = hapus tag html
from bs4 import BeautifulSoup 
import re # regular expressions (regex)

# natural language tool kits
from nltk.corpus import stopwords
import nltk

# word2vec library
from gensim.models import word2vec
import itertools

# library untuk Random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# path dataset
data_path = r'/content/drive/MyDrive/Text Dataset/IMDB Dataset.csv'
dataset = pd.read_csv(data_path, header=0, sep = ',')

# splitting data
train = dataset[0:39999]
test = dataset[40000:49999]

# %% [markdown]
# **Preprocessing Dataset**

# %%
# proprocessing data teks
def review_wordlist(review, remove_stopwords=False):
    
    # hapus tag html
    review_text = BeautifulSoup(review).get_text()
    
    # hapus simbol
    review_text = re.sub("[^a-zA-Z]"," ",review_text)
    
    # konversi ke huruf kecil dan dipisah perkata
    words = review_text.lower().split()

    # menghapus stopwords
    if remove_stopwords:
        stops = set(stopwords.words("english"))     
        words = [w for w in words if not w in stops]
    
    return(words)

# %%
# download file punctuation and stpwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# word2vec expects a list of lists.
# Using punkt tokenizer for better splitting of a paragraph into sentences.

import nltk.data
#nltk.download('popular')

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
# Memisah review per kalimat
def review_sentences(review, tokenizer, remove_stopwords=False):
    
    # melakukan tokenize dengan nltk tokenizer
    raw_sentences = tokenizer.tokenize(review.strip())
    sentences = []

    # mengisi array sentences dengan masing - masing review
    for raw_sentence in raw_sentences:
        if len(raw_sentence)>0:
            sentences.append(review_wordlist(raw_sentence,\
                                            remove_stopwords))

    # list dari list
    return sentences

# %%
sentences = []
print("Parsing sentences from training set")
for review in train["review"]:
    sentences += review_sentences(review, tokenizer)
# Out:
# Parsing sentences from training set
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:273: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:273: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "http://www.happierabroad.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
# Importing the built-in logging module
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
print("List dari lists. Cek tipe data : ", type(sentences), " of ", type(sentences[0]))
print(sentences[10])
print(len(sentences))
# Out:
# List dari lists. Cek tipe data :  <class 'list'>  of  <class 'list'>
# ['a', 'wonderful', 'little', 'production']
# 428144

# %% [markdown]
# **SEARCH BEST COMBINATION PARAMETER**

# %%
best_score = []
best_parameter = []

# %%
# parameter yang akan dioptimasi
parm_dict = {
    'workers' : (4,),
    'size' : (300, 350, 400, 450, 500),
    'min_count' : (40,),
    'window' : (10,)
}

# melakukan x, dengan metode y, untuk z 
# optimization of feature dimension on word embedding based on vector size using grid search for sentimen analysis

def cust_param_search(parm_dict):

    score_best, parm_best = 0,()
    workers, size, min_count, window = [tup for k,tup in parm_dict.items()] # Individual parm tuples
    parm_combo = list(itertools.product(workers, size, min_count, window)) # Create all combinations
    
    print('\n==============================================================')
    print('PARAMETER')
    print('==============================================================')
    print(f'Total kombinasi parameter   : {len(parm_combo)}')
    print(f'Semua kombinasi parameter   : {parm_combo}')

    # Grid search
    i = 1
    for parms in parm_combo:

        print('\n==============================================================')
        print(f'{i}.\t Parameter : {parms}')
        print('==============================================================')
        
        w, s, m, wi = parms
        
        # =================================================================================
        # word2vec mulai disini
        # =================================================================================
        
        # word2vec model
        model = word2vec.Word2Vec(workers = w, 
                              size = s, 
                              min_count = m, 
                              window = wi)
        model.build_vocab(sentences)

        # training model word2vec (CBOW, karena parameter 'sg' menggunakan nilai default)
        print('\n==============================================================')
        print("Training model Word2Vec ...")
        print('==============================================================')
        model.train(sentences = sentences, total_examples = len(sentences), epochs = 5)

        # Function to average all word vectors in a paragraph
        def featureVecMethod(words, model, num_features):
            # Pre-initialising empty numpy array for speed
            featureVec = np.zeros(s,dtype="float32")
            nwords = 0
            
            #Converting Index2Word which is a list to a set for better speed in the execution.
            index2word_set = set(model.wv.index2word)
            
            for word in  words:
                if word in index2word_set:
                    nwords = nwords + 1
                    featureVec = np.add(featureVec,model[word])
            
            # Dividing the result by number of words to get average
            featureVec = np.divide(featureVec, nwords)
            return featureVec

        # Function for calculating the average feature vector
        def getAvgFeatureVecs(reviews, model, num_features):
            counter = 0
            reviewFeatureVecs = np.zeros((len(reviews),s),dtype="float32")
            for review in reviews:
                # Printing a status message every 1000th review
                if counter%1000 == 0:
                    print("Review %d of %d"%(counter,len(reviews)))
                    
                reviewFeatureVecs[counter] = featureVecMethod(review, model, s)
                counter = counter+1
                
            return reviewFeatureVecs

        # Calculating average feature vector (mendapatkan vektor training set)
        clean_train_reviews = []
        for review in train['review']:
            clean_train_reviews.append(review_wordlist(review, remove_stopwords=True))
            
        trainDataVecs = getAvgFeatureVecs(clean_train_reviews, model, s)

        # Calculating average feature vactors (mendapatkan vektor test set)     
        clean_test_reviews = []
        for review in test["review"]:
            clean_test_reviews.append(review_wordlist(review,remove_stopwords=True))
            
        testDataVecs = getAvgFeatureVecs(clean_test_reviews, model, s)

        # tujuan masing-masing model word2vec, untuk mendapatkan 'trainDataVecs' dan 'testDataVecs' 
        # untuk diolah lebih lanjut di classifier
        
        # =================================================================================
        # word2vec berakhir disini
        # =================================================================================

        print('\n==============================================================')
        print('Sentiment Analysis Process ...')
        print('==============================================================')
        # Memanggil classifier
        score, report = classification_model(trainDataVecs, testDataVecs, train["sentiment"], test["sentiment"])

        # temporary print
        print('\n==============================================================')
        print(f'Hasil Test Parameter ke - {i}')
        print(f'Parameter  => {parms}')
        print(f'Accuracy   => {score}')
        print(f'Classification Report => \n {report}')
        print('==============================================================')

        best_score.append(score)
        best_parameter.append(parms)
        
        if score > score_best:
            score_best = score
            parm_best = parms
        
        i = i + 1
    
    print('\n==============================================================')
    print(f'Best Parameter  => {parm_best}')
    print(f'Accuracy   => {score_best}')
    print('==============================================================')

# %%
def classification_model(train_feature_vec, test_feature_vec, train_sentiment, test_sentiment):

    # Model/classifier yang dipakai bebas
    # Fit random forest classifier ke data training
    forest = RandomForestClassifier(n_estimators = 100)    
    forest = forest.fit(train_feature_vec, train_sentiment) 

    # Prediksi nilai sentiment untuk test data 
    predicted = forest.predict(test_feature_vec)

    # akurasi
    accuracy = accuracy_score(test_sentiment, predicted)
    report = classification_report(test_sentiment, predicted, digits = 5)
    
    return accuracy, report

# %%
# test drive ma men (estimasi running : 17 menit)
cust_param_search(parm_dict)
# Out:
# 2020-12-22 15:08:26,791 : INFO : collecting all words and their counts
# 2020-12-22 15:08:26,792 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-12-22 15:08:26,851 : INFO : PROGRESS: at sentence #10000, processed 224307 words, keeping 17319 word types
# 2020-12-22 15:08:26,908 : INFO : PROGRESS: at sentence #20000, processed 434605 words, keeping 24175 word types
# 2020-12-22 15:08:26,967 : INFO : PROGRESS: at sentence #30000, processed 655533 words, keeping 29419 word types
# ==============================================================
# PARAMETER
# ==============================================================
# Total kombinasi parameter   : 7
# Semua kombinasi parameter   : [(4, 300, 40, 10), (4, 350, 40, 10), (4, 400, 40, 10), (4, 450, 40, 10), (4, 500, 40, 10), (4, 550, 40, 10), (4, 600, 40, 10)]
#
# ==============================================================
# 1.	 Parameter : (4, 300, 40, 10)
# ==============================================================
# 2020-12-22 15:08:27,029 : INFO : PROGRESS: at sentence #40000, processed 877306 words, keeping 33897 word types
# 2020-12-22 15:08:27,092 : INFO : PROGRESS: at sentence #50000, processed 1100000 words, keeping 37667 word types
# 2020-12-22 15:08:27,151 : INFO : PROGRESS: at sentence #60000, processed 1324580 words, keeping 40923 word types
# 2020-12-22 15:08:27,209 : INFO : PROGRESS: at sentence #70000, processed 1543432 words, keeping 43631 word types
# 2020-12-22 15:08:27,268 : INFO : PROGRESS: at sentence #80000, processed 1757050 words, keeping 46072 word types
# 2020-12-22 15:08:27,330 : INFO : PROGRESS: at sentence #90000, processed 1976526 words, keeping 48547 word types
# 2020-12-22 15:08:27,398 : INFO : PROGRESS: at sentence #100000, processed 2199610 words, keeping 50850 word types
# 2020-12-22 15:08:27,473 : INFO : PROGRESS: at sentence #110000, processed 2412028 words, keeping 52887 word types
# 2020-12-22 15:08:27,538 : INFO : PROGRESS: at sentence #120000, processed 2631483 words, keeping 54897 word types
# 2020-12-22 15:08:27,607 : INFO : PROGRESS: at sentence #130000, processed 2852491 words, keeping 56806 word types
# 2020-12-22 15:08:27,668 : INFO : PROGRESS: at sentence #140000, processed 3074705 words, keeping 58479 word types
# 2020-12-22 15:08:27,733 : INFO : PROGRESS: at sentence #150000, processed 3290599 words, keeping 59976 word types
# 2020-12-22 15:08:27,802 : INFO : PROGRESS: at sentence #160000, processed 3503070 words, keeping 61583 word types
# 2020-12-22 15:08:27,860 : INFO : PROGRESS: at sentence #170000, processed 3718687 words, keeping 63166 word types
# 2020-12-22 15:08:27,924 : INFO : PROGRESS: at sentence #180000, processed 3941039 words, keeping 64688 word types
# 2020-12-22 15:08:27,984 : INFO : PROGRESS: at sentence #190000, processed 4159717 words, keeping 66133 word types
# 2020-12-22 15:08:28,045 : INFO : PROGRESS: at sentence #200000, processed 4377455 words, keeping 67536 word types
# 2020-12-22 15:08:28,103 : INFO : PROGRESS: at sentence #210000, processed 4593514 words, keeping 68843 word types
# 2020-12-22 15:08:28,165 : INFO : PROGRESS: at sentence #220000, processed 4813310 words, keeping 70117 word types
# 2020-12-22 15:08:28,224 : INFO : PROGRESS: at sentence #230000, processed 5034508 words, keeping 71484 word types
# 2020-12-22 15:08:28,283 : INFO : PROGRESS: at sentence #240000, processed 5255583 words, keeping 72687 word types
# 2020-12-22 15:08:28,342 : INFO : PROGRESS: at sentence #250000, processed 5476579 words, keeping 73951 word types
# 2020-12-22 15:08:28,399 : INFO : PROGRESS: at sentence #260000, processed 5694195 words, keeping 75064 word types
# 2020-12-22 15:08:28,459 : INFO : PROGRESS: at sentence #270000, processed 5913181 words, keeping 76181 word types
# 2020-12-22 15:08:28,524 : INFO : PROGRESS: at sentence #280000, processed 6134877 words, keeping 77335 word types
# 2020-12-22 15:08:28,592 : INFO : PROGRESS: at sentence #290000, processed 6349950 words, keeping 78484 word types
# 2020-12-22 15:08:28,654 : INFO : PROGRESS: at sentence #300000, processed 6569736 words, keeping 79593 word types
# 2020-12-22 15:08:28,716 : INFO : PROGRESS: at sentence #310000, processed 6786686 words, keeping 80756 word types
# 2020-12-22 15:08:28,785 : INFO : PROGRESS: at sentence #320000, processed 7007919 words, keeping 81790 word types
# 2020-12-22 15:08:28,853 : INFO : PROGRESS: at sentence #330000, processed 7225676 words, keeping 82863 word types
# 2020-12-22 15:08:28,913 : INFO : PROGRESS: at sentence #340000, processed 7442546 words, keeping 83964 word types
# 2020-12-22 15:08:28,974 : INFO : PROGRESS: at sentence #350000, processed 7662724 words, keeping 84962 word types
# 2020-12-22 15:08:29,038 : INFO : PROGRESS: at sentence #360000, processed 7877591 words, keeping 85892 word types
# 2020-12-22 15:08:29,100 : INFO : PROGRESS: at sentence #370000, processed 8097606 words, keeping 86955 word types
# 2020-12-22 15:08:29,173 : INFO : PROGRESS: at sentence #380000, processed 8314768 words, keeping 87912 word types
# 2020-12-22 15:08:29,234 : INFO : PROGRESS: at sentence #390000, processed 8528660 words, keeping 88820 word types
# 2020-12-22 15:08:29,295 : INFO : PROGRESS: at sentence #400000, processed 8743911 words, keeping 89812 word types
# 2020-12-22 15:08:29,365 : INFO : PROGRESS: at sentence #410000, processed 8961785 words, keeping 90762 word types
# 2020-12-22 15:08:29,428 : INFO : PROGRESS: at sentence #420000, processed 9174372 words, keeping 91593 word types
# 2020-12-22 15:08:29,481 : INFO : collected 92280 word types from a corpus of 9353984 raw words and 428144 sentences
# 2020-12-22 15:08:29,482 : INFO : Loading a fresh vocabulary
# 2020-12-22 15:08:29,544 : INFO : effective_min_count=40 retains 11183 unique words (12% of original 92280, drops 81097)
# 2020-12-22 15:08:29,544 : INFO : effective_min_count=40 leaves 8916177 word corpus (95% of original 9353984, drops 437807)
# 2020-12-22 15:08:29,586 : INFO : deleting the raw counts dictionary of 92280 items
# 2020-12-22 15:08:29,591 : INFO : sample=0.001 downsamples 49 most-common words
# 2020-12-22 15:08:29,592 : INFO : downsampling leaves estimated 6535286 word corpus (73.3% of prior 8916177)
# 2020-12-22 15:08:29,640 : INFO : estimated required memory for 11183 words and 300 dimensions: 32430700 bytes
# 2020-12-22 15:08:29,641 : INFO : resetting layer weights
# 2020-12-22 15:08:32,065 : INFO : training model with 4 workers on 11183 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# ==============================================================
# Training model Word2Vec ...
# ==============================================================
# 2020-12-22 15:08:33,103 : INFO : EPOCH 1 - PROGRESS: at 5.24% examples, 332533 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:08:34,134 : INFO : EPOCH 1 - PROGRESS: at 10.73% examples, 342093 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:08:35,146 : INFO : EPOCH 1 - PROGRESS: at 16.20% examples, 347376 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:36,164 : INFO : EPOCH 1 - PROGRESS: at 21.67% examples, 347892 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:08:37,175 : INFO : EPOCH 1 - PROGRESS: at 27.22% examples, 349822 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:08:38,208 : INFO : EPOCH 1 - PROGRESS: at 32.69% examples, 349918 words/s, in_qsize 4, out_qsize 3
# 2020-12-22 15:08:39,209 : INFO : EPOCH 1 - PROGRESS: at 38.36% examples, 351776 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:40,247 : INFO : EPOCH 1 - PROGRESS: at 43.75% examples, 350597 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:08:41,271 : INFO : EPOCH 1 - PROGRESS: at 49.33% examples, 351042 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:42,273 : INFO : EPOCH 1 - PROGRESS: at 54.73% examples, 351334 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:08:43,276 : INFO : EPOCH 1 - PROGRESS: at 60.14% examples, 351667 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:44,303 : INFO : EPOCH 1 - PROGRESS: at 65.55% examples, 351240 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:45,308 : INFO : EPOCH 1 - PROGRESS: at 71.13% examples, 351952 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:46,346 : INFO : EPOCH 1 - PROGRESS: at 76.77% examples, 352233 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:47,362 : INFO : EPOCH 1 - PROGRESS: at 81.99% examples, 351143 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:08:48,372 : INFO : EPOCH 1 - PROGRESS: at 87.59% examples, 351595 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:49,378 : INFO : EPOCH 1 - PROGRESS: at 93.32% examples, 352536 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:50,384 : INFO : EPOCH 1 - PROGRESS: at 98.50% examples, 351502 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:08:50,597 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:08:50,604 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:08:50,607 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:08:50,609 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:08:50,610 : INFO : EPOCH - 1 : training on 9353984 raw words (6534880 effective words) took 18.5s, 352552 effective words/s
# 2020-12-22 15:08:51,676 : INFO : EPOCH 2 - PROGRESS: at 5.46% examples, 337859 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:08:52,713 : INFO : EPOCH 2 - PROGRESS: at 11.04% examples, 346962 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:53,717 : INFO : EPOCH 2 - PROGRESS: at 16.28% examples, 347155 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:08:54,752 : INFO : EPOCH 2 - PROGRESS: at 21.98% examples, 349606 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:08:55,783 : INFO : EPOCH 2 - PROGRESS: at 27.43% examples, 348438 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:56,809 : INFO : EPOCH 2 - PROGRESS: at 33.12% examples, 351540 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:57,833 : INFO : EPOCH 2 - PROGRESS: at 38.79% examples, 351972 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:58,833 : INFO : EPOCH 2 - PROGRESS: at 44.19% examples, 352461 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:08:59,885 : INFO : EPOCH 2 - PROGRESS: at 49.75% examples, 351581 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:00,886 : INFO : EPOCH 2 - PROGRESS: at 55.27% examples, 352611 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:09:01,890 : INFO : EPOCH 2 - PROGRESS: at 60.78% examples, 353372 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:02,944 : INFO : EPOCH 2 - PROGRESS: at 66.53% examples, 353658 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:09:03,945 : INFO : EPOCH 2 - PROGRESS: at 72.19% examples, 354820 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:04,950 : INFO : EPOCH 2 - PROGRESS: at 77.39% examples, 353764 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:09:05,977 : INFO : EPOCH 2 - PROGRESS: at 83.19% examples, 354597 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:07,001 : INFO : EPOCH 2 - PROGRESS: at 88.87% examples, 354949 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:08,012 : INFO : EPOCH 2 - PROGRESS: at 94.48% examples, 355208 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:08,906 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:09:08,918 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:09:08,938 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:09:08,944 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:09:08,945 : INFO : EPOCH - 2 : training on 9353984 raw words (6534839 effective words) took 18.3s, 356618 effective words/s
# 2020-12-22 15:09:09,972 : INFO : EPOCH 3 - PROGRESS: at 5.35% examples, 343452 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:10,974 : INFO : EPOCH 3 - PROGRESS: at 10.95% examples, 355756 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:11,976 : INFO : EPOCH 3 - PROGRESS: at 16.18% examples, 353083 words/s, in_qsize 8, out_qsize 0
# 2020-12-22 15:09:13,017 : INFO : EPOCH 3 - PROGRESS: at 21.78% examples, 352050 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:14,048 : INFO : EPOCH 3 - PROGRESS: at 27.54% examples, 354471 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:15,060 : INFO : EPOCH 3 - PROGRESS: at 33.12% examples, 356289 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:16,129 : INFO : EPOCH 3 - PROGRESS: at 38.90% examples, 354795 words/s, in_qsize 6, out_qsize 2
# 2020-12-22 15:09:17,134 : INFO : EPOCH 3 - PROGRESS: at 44.20% examples, 353860 words/s, in_qsize 4, out_qsize 3
# 2020-12-22 15:09:18,159 : INFO : EPOCH 3 - PROGRESS: at 50.10% examples, 356181 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:19,177 : INFO : EPOCH 3 - PROGRESS: at 55.59% examples, 356071 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:20,184 : INFO : EPOCH 3 - PROGRESS: at 61.11% examples, 356435 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:21,213 : INFO : EPOCH 3 - PROGRESS: at 66.74% examples, 356667 words/s, in_qsize 8, out_qsize 1
# 2020-12-22 15:09:22,237 : INFO : EPOCH 3 - PROGRESS: at 72.42% examples, 356996 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:23,243 : INFO : EPOCH 3 - PROGRESS: at 77.83% examples, 356742 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:24,285 : INFO : EPOCH 3 - PROGRESS: at 83.53% examples, 356581 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:25,312 : INFO : EPOCH 3 - PROGRESS: at 89.20% examples, 356740 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:26,345 : INFO : EPOCH 3 - PROGRESS: at 94.81% examples, 356408 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:27,190 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:09:27,198 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:09:27,222 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:09:27,223 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:09:27,224 : INFO : EPOCH - 3 : training on 9353984 raw words (6534818 effective words) took 18.3s, 357673 effective words/s
# 2020-12-22 15:09:28,243 : INFO : EPOCH 4 - PROGRESS: at 5.34% examples, 347377 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:29,245 : INFO : EPOCH 4 - PROGRESS: at 10.73% examples, 350881 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:30,305 : INFO : EPOCH 4 - PROGRESS: at 16.28% examples, 350049 words/s, in_qsize 4, out_qsize 3
# 2020-12-22 15:09:31,317 : INFO : EPOCH 4 - PROGRESS: at 21.99% examples, 353898 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:32,322 : INFO : EPOCH 4 - PROGRESS: at 27.32% examples, 352352 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:33,347 : INFO : EPOCH 4 - PROGRESS: at 32.81% examples, 352583 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:09:34,349 : INFO : EPOCH 4 - PROGRESS: at 38.57% examples, 354929 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:35,351 : INFO : EPOCH 4 - PROGRESS: at 44.30% examples, 357540 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:36,360 : INFO : EPOCH 4 - PROGRESS: at 49.88% examples, 357775 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:37,398 : INFO : EPOCH 4 - PROGRESS: at 55.38% examples, 356865 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:38,400 : INFO : EPOCH 4 - PROGRESS: at 60.67% examples, 356042 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:39,420 : INFO : EPOCH 4 - PROGRESS: at 66.21% examples, 355964 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:40,429 : INFO : EPOCH 4 - PROGRESS: at 71.76% examples, 356232 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:41,443 : INFO : EPOCH 4 - PROGRESS: at 77.40% examples, 356797 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:42,453 : INFO : EPOCH 4 - PROGRESS: at 82.86% examples, 356446 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:43,471 : INFO : EPOCH 4 - PROGRESS: at 88.32% examples, 355964 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:44,481 : INFO : EPOCH 4 - PROGRESS: at 93.94% examples, 356180 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:45,485 : INFO : EPOCH 4 - PROGRESS: at 99.35% examples, 355735 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:45,518 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:09:45,545 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:09:45,558 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:09:45,561 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:09:45,563 : INFO : EPOCH - 4 : training on 9353984 raw words (6534501 effective words) took 18.3s, 356571 effective words/s
# 2020-12-22 15:09:46,588 : INFO : EPOCH 5 - PROGRESS: at 5.24% examples, 339070 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:47,632 : INFO : EPOCH 5 - PROGRESS: at 10.63% examples, 339812 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:48,671 : INFO : EPOCH 5 - PROGRESS: at 16.09% examples, 342709 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:09:49,697 : INFO : EPOCH 5 - PROGRESS: at 21.67% examples, 345467 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:50,703 : INFO : EPOCH 5 - PROGRESS: at 27.21% examples, 348295 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:51,724 : INFO : EPOCH 5 - PROGRESS: at 32.71% examples, 349467 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:52,728 : INFO : EPOCH 5 - PROGRESS: at 38.24% examples, 350189 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:53,776 : INFO : EPOCH 5 - PROGRESS: at 43.98% examples, 351393 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:54,777 : INFO : EPOCH 5 - PROGRESS: at 49.55% examples, 352611 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:55,782 : INFO : EPOCH 5 - PROGRESS: at 54.93% examples, 352692 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:56,821 : INFO : EPOCH 5 - PROGRESS: at 60.57% examples, 353002 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:57,824 : INFO : EPOCH 5 - PROGRESS: at 66.10% examples, 353683 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:58,864 : INFO : EPOCH 5 - PROGRESS: at 71.76% examples, 353827 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:09:59,872 : INFO : EPOCH 5 - PROGRESS: at 77.40% examples, 354722 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:10:00,878 : INFO : EPOCH 5 - PROGRESS: at 82.98% examples, 355091 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:10:01,889 : INFO : EPOCH 5 - PROGRESS: at 88.53% examples, 355291 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:10:02,894 : INFO : EPOCH 5 - PROGRESS: at 94.04% examples, 355245 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:10:03,872 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:10:03,898 : INFO : EPOCH 5 - PROGRESS: at 99.80% examples, 356054 words/s, in_qsize 2, out_qsize 1
# 2020-12-22 15:10:03,899 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:10:03,908 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:10:03,922 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:10:03,923 : INFO : EPOCH - 5 : training on 9353984 raw words (6536262 effective words) took 18.3s, 356324 effective words/s
# 2020-12-22 15:10:03,924 : INFO : training on a 46769920 raw words (32675300 effective words) took 91.9s, 355718 effective words/s
# Review 0 of 39999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:63: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Review 1000 of 39999
# Review 2000 of 39999
# Review 3000 of 39999
# Review 4000 of 39999
# Review 5000 of 39999
# Review 6000 of 39999
# Review 7000 of 39999
# Review 8000 of 39999
# Review 9000 of 39999
# Review 10000 of 39999
# Review 11000 of 39999
# Review 12000 of 39999
# Review 13000 of 39999
# Review 14000 of 39999
# Review 15000 of 39999
# Review 16000 of 39999
# Review 17000 of 39999
# Review 18000 of 39999
# Review 19000 of 39999
# Review 20000 of 39999
# Review 21000 of 39999
# Review 22000 of 39999
# Review 23000 of 39999
# Review 24000 of 39999
# Review 25000 of 39999
# Review 26000 of 39999
# Review 27000 of 39999
# Review 28000 of 39999
# Review 29000 of 39999
# Review 30000 of 39999
# Review 31000 of 39999
# Review 32000 of 39999
# Review 33000 of 39999
# Review 34000 of 39999
# Review 35000 of 39999
# Review 36000 of 39999
# Review 37000 of 39999
# Review 38000 of 39999
# Review 39000 of 39999
# Review 0 of 9999
# Review 1000 of 9999
# Review 2000 of 9999
# Review 3000 of 9999
# Review 4000 of 9999
# Review 5000 of 9999
# Review 6000 of 9999
# Review 7000 of 9999
# Review 8000 of 9999
# Review 9000 of 9999
#
# ==============================================================
# Sentiment Analysis Process ...
# ==============================================================
# 2020-12-22 15:13:28,508 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-12-22 15:13:28,513 : INFO : collecting all words and their counts
# 2020-12-22 15:13:28,515 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-12-22 15:13:28,571 : INFO : PROGRESS: at sentence #10000, processed 224307 words, keeping 17319 word types
# 2020-12-22 15:13:28,620 : INFO : PROGRESS: at sentence #20000, processed 434605 words, keeping 24175 word types
# 2020-12-22 15:13:28,676 : INFO : PROGRESS: at sentence #30000, processed 655533 words, keeping 29419 word types
# ==============================================================
# Hasil Test Parameter ke - 1
# Parameter  => (4, 300, 40, 10)
# Accuracy   => 0.8283828382838284
# Classification Report =>
#                precision    recall  f1-score   support
#
#     negative    0.84239   0.80729   0.82447      4992
#     positive    0.81553   0.84941   0.83213      5007
#
#     accuracy                        0.82838      9999
#    macro avg    0.82896   0.82835   0.82830      9999
# weighted avg    0.82894   0.82838   0.82830      9999
#
# ==============================================================
#
# ==============================================================
# 2.	 Parameter : (4, 350, 40, 10)
# ==============================================================
# 2020-12-22 15:13:28,733 : INFO : PROGRESS: at sentence #40000, processed 877306 words, keeping 33897 word types
# 2020-12-22 15:13:28,791 : INFO : PROGRESS: at sentence #50000, processed 1100000 words, keeping 37667 word types
# 2020-12-22 15:13:28,853 : INFO : PROGRESS: at sentence #60000, processed 1324580 words, keeping 40923 word types
# 2020-12-22 15:13:28,907 : INFO : PROGRESS: at sentence #70000, processed 1543432 words, keeping 43631 word types
# 2020-12-22 15:13:28,966 : INFO : PROGRESS: at sentence #80000, processed 1757050 words, keeping 46072 word types
# 2020-12-22 15:13:29,024 : INFO : PROGRESS: at sentence #90000, processed 1976526 words, keeping 48547 word types
# 2020-12-22 15:13:29,080 : INFO : PROGRESS: at sentence #100000, processed 2199610 words, keeping 50850 word types
# 2020-12-22 15:13:29,132 : INFO : PROGRESS: at sentence #110000, processed 2412028 words, keeping 52887 word types
# 2020-12-22 15:13:29,186 : INFO : PROGRESS: at sentence #120000, processed 2631483 words, keeping 54897 word types
# 2020-12-22 15:13:29,245 : INFO : PROGRESS: at sentence #130000, processed 2852491 words, keeping 56806 word types
# 2020-12-22 15:13:29,302 : INFO : PROGRESS: at sentence #140000, processed 3074705 words, keeping 58479 word types
# 2020-12-22 15:13:29,360 : INFO : PROGRESS: at sentence #150000, processed 3290599 words, keeping 59976 word types
# 2020-12-22 15:13:29,415 : INFO : PROGRESS: at sentence #160000, processed 3503070 words, keeping 61583 word types
# 2020-12-22 15:13:29,468 : INFO : PROGRESS: at sentence #170000, processed 3718687 words, keeping 63166 word types
# 2020-12-22 15:13:29,522 : INFO : PROGRESS: at sentence #180000, processed 3941039 words, keeping 64688 word types
# 2020-12-22 15:13:29,579 : INFO : PROGRESS: at sentence #190000, processed 4159717 words, keeping 66133 word types
# 2020-12-22 15:13:29,636 : INFO : PROGRESS: at sentence #200000, processed 4377455 words, keeping 67536 word types
# 2020-12-22 15:13:29,694 : INFO : PROGRESS: at sentence #210000, processed 4593514 words, keeping 68843 word types
# 2020-12-22 15:13:29,754 : INFO : PROGRESS: at sentence #220000, processed 4813310 words, keeping 70117 word types
# 2020-12-22 15:13:29,810 : INFO : PROGRESS: at sentence #230000, processed 5034508 words, keeping 71484 word types
# 2020-12-22 15:13:29,871 : INFO : PROGRESS: at sentence #240000, processed 5255583 words, keeping 72687 word types
# 2020-12-22 15:13:29,928 : INFO : PROGRESS: at sentence #250000, processed 5476579 words, keeping 73951 word types
# 2020-12-22 15:13:29,983 : INFO : PROGRESS: at sentence #260000, processed 5694195 words, keeping 75064 word types
# 2020-12-22 15:13:30,041 : INFO : PROGRESS: at sentence #270000, processed 5913181 words, keeping 76181 word types
# 2020-12-22 15:13:30,103 : INFO : PROGRESS: at sentence #280000, processed 6134877 words, keeping 77335 word types
# 2020-12-22 15:13:30,160 : INFO : PROGRESS: at sentence #290000, processed 6349950 words, keeping 78484 word types
# 2020-12-22 15:13:30,217 : INFO : PROGRESS: at sentence #300000, processed 6569736 words, keeping 79593 word types
# 2020-12-22 15:13:30,274 : INFO : PROGRESS: at sentence #310000, processed 6786686 words, keeping 80756 word types
# 2020-12-22 15:13:30,332 : INFO : PROGRESS: at sentence #320000, processed 7007919 words, keeping 81790 word types
# 2020-12-22 15:13:30,388 : INFO : PROGRESS: at sentence #330000, processed 7225676 words, keeping 82863 word types
# 2020-12-22 15:13:30,444 : INFO : PROGRESS: at sentence #340000, processed 7442546 words, keeping 83964 word types
# 2020-12-22 15:13:30,500 : INFO : PROGRESS: at sentence #350000, processed 7662724 words, keeping 84962 word types
# 2020-12-22 15:13:30,559 : INFO : PROGRESS: at sentence #360000, processed 7877591 words, keeping 85892 word types
# 2020-12-22 15:13:30,616 : INFO : PROGRESS: at sentence #370000, processed 8097606 words, keeping 86955 word types
# 2020-12-22 15:13:30,673 : INFO : PROGRESS: at sentence #380000, processed 8314768 words, keeping 87912 word types
# 2020-12-22 15:13:30,728 : INFO : PROGRESS: at sentence #390000, processed 8528660 words, keeping 88820 word types
# 2020-12-22 15:13:30,783 : INFO : PROGRESS: at sentence #400000, processed 8743911 words, keeping 89812 word types
# 2020-12-22 15:13:30,839 : INFO : PROGRESS: at sentence #410000, processed 8961785 words, keeping 90762 word types
# 2020-12-22 15:13:30,900 : INFO : PROGRESS: at sentence #420000, processed 9174372 words, keeping 91593 word types
# 2020-12-22 15:13:30,947 : INFO : collected 92280 word types from a corpus of 9353984 raw words and 428144 sentences
# 2020-12-22 15:13:30,948 : INFO : Loading a fresh vocabulary
# 2020-12-22 15:13:31,007 : INFO : effective_min_count=40 retains 11183 unique words (12% of original 92280, drops 81097)
# 2020-12-22 15:13:31,008 : INFO : effective_min_count=40 leaves 8916177 word corpus (95% of original 9353984, drops 437807)
# 2020-12-22 15:13:31,050 : INFO : deleting the raw counts dictionary of 92280 items
# 2020-12-22 15:13:31,054 : INFO : sample=0.001 downsamples 49 most-common words
# 2020-12-22 15:13:31,060 : INFO : downsampling leaves estimated 6535286 word corpus (73.3% of prior 8916177)
# 2020-12-22 15:13:31,100 : INFO : estimated required memory for 11183 words and 350 dimensions: 36903900 bytes
# 2020-12-22 15:13:31,103 : INFO : resetting layer weights
# 2020-12-22 15:13:33,501 : INFO : training model with 4 workers on 11183 vocabulary and 350 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# ==============================================================
# Training model Word2Vec ...
# ==============================================================
# 2020-12-22 15:13:34,556 : INFO : EPOCH 1 - PROGRESS: at 4.39% examples, 274269 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:35,575 : INFO : EPOCH 1 - PROGRESS: at 8.83% examples, 280839 words/s, in_qsize 8, out_qsize 0
# 2020-12-22 15:13:36,590 : INFO : EPOCH 1 - PROGRESS: at 13.22% examples, 284267 words/s, in_qsize 8, out_qsize 1
# 2020-12-22 15:13:37,605 : INFO : EPOCH 1 - PROGRESS: at 17.70% examples, 284485 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:38,667 : INFO : EPOCH 1 - PROGRESS: at 22.29% examples, 284045 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:13:39,682 : INFO : EPOCH 1 - PROGRESS: at 27.01% examples, 286940 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:40,700 : INFO : EPOCH 1 - PROGRESS: at 31.33% examples, 286096 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:41,701 : INFO : EPOCH 1 - PROGRESS: at 35.51% examples, 284391 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:13:42,755 : INFO : EPOCH 1 - PROGRESS: at 39.75% examples, 281407 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:13:43,803 : INFO : EPOCH 1 - PROGRESS: at 43.75% examples, 278509 words/s, in_qsize 4, out_qsize 3
# 2020-12-22 15:13:44,818 : INFO : EPOCH 1 - PROGRESS: at 48.51% examples, 280649 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:45,875 : INFO : EPOCH 1 - PROGRESS: at 52.94% examples, 280340 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:46,894 : INFO : EPOCH 1 - PROGRESS: at 57.48% examples, 281392 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:47,923 : INFO : EPOCH 1 - PROGRESS: at 61.95% examples, 281626 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:48,931 : INFO : EPOCH 1 - PROGRESS: at 65.98% examples, 280393 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:49,933 : INFO : EPOCH 1 - PROGRESS: at 70.36% examples, 280699 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:51,006 : INFO : EPOCH 1 - PROGRESS: at 74.95% examples, 280632 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:13:52,049 : INFO : EPOCH 1 - PROGRESS: at 79.67% examples, 281376 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:53,090 : INFO : EPOCH 1 - PROGRESS: at 84.29% examples, 281714 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:54,115 : INFO : EPOCH 1 - PROGRESS: at 88.87% examples, 282218 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:55,117 : INFO : EPOCH 1 - PROGRESS: at 93.32% examples, 282367 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:13:56,129 : INFO : EPOCH 1 - PROGRESS: at 97.61% examples, 282085 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:13:56,582 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:13:56,584 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:13:56,612 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:13:56,631 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:13:56,633 : INFO : EPOCH - 1 : training on 9353984 raw words (6535680 effective words) took 23.1s, 282659 effective words/s
# 2020-12-22 15:13:57,678 : INFO : EPOCH 2 - PROGRESS: at 4.17% examples, 268847 words/s, in_qsize 8, out_qsize 1
# 2020-12-22 15:13:58,664 : INFO : EPOCH 2 - PROGRESS: at 8.50% examples, 276638 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:13:59,683 : INFO : EPOCH 2 - PROGRESS: at 13.02% examples, 282479 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:00,685 : INFO : EPOCH 2 - PROGRESS: at 17.49% examples, 284823 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:01,691 : INFO : EPOCH 2 - PROGRESS: at 21.88% examples, 284754 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:02,721 : INFO : EPOCH 2 - PROGRESS: at 26.36% examples, 284511 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:03,726 : INFO : EPOCH 2 - PROGRESS: at 30.91% examples, 286491 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:04,742 : INFO : EPOCH 2 - PROGRESS: at 35.39% examples, 286700 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:05,746 : INFO : EPOCH 2 - PROGRESS: at 39.85% examples, 286455 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:06,770 : INFO : EPOCH 2 - PROGRESS: at 44.29% examples, 286439 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:07,774 : INFO : EPOCH 2 - PROGRESS: at 48.72% examples, 286276 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:14:08,788 : INFO : EPOCH 2 - PROGRESS: at 53.16% examples, 286451 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:09,845 : INFO : EPOCH 2 - PROGRESS: at 57.79% examples, 286759 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:10,883 : INFO : EPOCH 2 - PROGRESS: at 62.39% examples, 286938 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:11,921 : INFO : EPOCH 2 - PROGRESS: at 66.85% examples, 286614 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:12,989 : INFO : EPOCH 2 - PROGRESS: at 71.45% examples, 286270 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:14,016 : INFO : EPOCH 2 - PROGRESS: at 76.01% examples, 286585 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:15,021 : INFO : EPOCH 2 - PROGRESS: at 80.51% examples, 286810 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:16,040 : INFO : EPOCH 2 - PROGRESS: at 84.62% examples, 285378 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:17,045 : INFO : EPOCH 2 - PROGRESS: at 89.20% examples, 285999 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:18,054 : INFO : EPOCH 2 - PROGRESS: at 93.52% examples, 285552 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:19,074 : INFO : EPOCH 2 - PROGRESS: at 98.08% examples, 285664 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:19,398 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:14:19,418 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:14:19,444 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:14:19,468 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:14:19,469 : INFO : EPOCH - 2 : training on 9353984 raw words (6533916 effective words) took 22.8s, 286281 effective words/s
# 2020-12-22 15:14:20,528 : INFO : EPOCH 3 - PROGRESS: at 4.07% examples, 252785 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:21,554 : INFO : EPOCH 3 - PROGRESS: at 8.29% examples, 261957 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:22,601 : INFO : EPOCH 3 - PROGRESS: at 12.92% examples, 272319 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:23,635 : INFO : EPOCH 3 - PROGRESS: at 17.16% examples, 271559 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:24,641 : INFO : EPOCH 3 - PROGRESS: at 21.57% examples, 274083 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:25,661 : INFO : EPOCH 3 - PROGRESS: at 26.05% examples, 276196 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:26,700 : INFO : EPOCH 3 - PROGRESS: at 30.49% examples, 276995 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:14:27,706 : INFO : EPOCH 3 - PROGRESS: at 34.96% examples, 278800 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:28,713 : INFO : EPOCH 3 - PROGRESS: at 39.64% examples, 280844 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:29,739 : INFO : EPOCH 3 - PROGRESS: at 44.10% examples, 281329 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:30,772 : INFO : EPOCH 3 - PROGRESS: at 48.71% examples, 282135 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:31,783 : INFO : EPOCH 3 - PROGRESS: at 53.16% examples, 282747 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:32,804 : INFO : EPOCH 3 - PROGRESS: at 57.38% examples, 282129 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:33,833 : INFO : EPOCH 3 - PROGRESS: at 61.85% examples, 282209 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:34,846 : INFO : EPOCH 3 - PROGRESS: at 66.31% examples, 282696 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:35,858 : INFO : EPOCH 3 - PROGRESS: at 70.70% examples, 282662 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:36,921 : INFO : EPOCH 3 - PROGRESS: at 75.38% examples, 283019 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:37,948 : INFO : EPOCH 3 - PROGRESS: at 79.97% examples, 283478 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:38,981 : INFO : EPOCH 3 - PROGRESS: at 84.39% examples, 283121 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:40,001 : INFO : EPOCH 3 - PROGRESS: at 88.87% examples, 283296 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:41,008 : INFO : EPOCH 3 - PROGRESS: at 93.31% examples, 283327 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:42,046 : INFO : EPOCH 3 - PROGRESS: at 97.83% examples, 283294 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:42,471 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:14:42,483 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:14:42,493 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:14:42,503 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:14:42,504 : INFO : EPOCH - 3 : training on 9353984 raw words (6534401 effective words) took 23.0s, 283780 effective words/s
# 2020-12-22 15:14:43,527 : INFO : EPOCH 4 - PROGRESS: at 4.06% examples, 262932 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:44,528 : INFO : EPOCH 4 - PROGRESS: at 8.50% examples, 277860 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:45,614 : INFO : EPOCH 4 - PROGRESS: at 13.02% examples, 277413 words/s, in_qsize 7, out_qsize 2
# 2020-12-22 15:14:46,683 : INFO : EPOCH 4 - PROGRESS: at 17.70% examples, 279646 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:47,690 : INFO : EPOCH 4 - PROGRESS: at 21.88% examples, 277884 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:48,721 : INFO : EPOCH 4 - PROGRESS: at 26.35% examples, 278781 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:49,735 : INFO : EPOCH 4 - PROGRESS: at 31.00% examples, 282108 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:50,788 : INFO : EPOCH 4 - PROGRESS: at 35.29% examples, 279911 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:51,826 : INFO : EPOCH 4 - PROGRESS: at 39.65% examples, 278674 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:52,828 : INFO : EPOCH 4 - PROGRESS: at 44.09% examples, 280013 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:53,838 : INFO : EPOCH 4 - PROGRESS: at 48.29% examples, 279040 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:54,877 : INFO : EPOCH 4 - PROGRESS: at 52.82% examples, 279842 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:55,895 : INFO : EPOCH 4 - PROGRESS: at 57.07% examples, 279371 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:56,922 : INFO : EPOCH 4 - PROGRESS: at 61.63% examples, 280271 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:14:57,959 : INFO : EPOCH 4 - PROGRESS: at 66.11% examples, 280431 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:14:58,974 : INFO : EPOCH 4 - PROGRESS: at 70.58% examples, 280948 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:00,020 : INFO : EPOCH 4 - PROGRESS: at 75.28% examples, 281721 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:01,027 : INFO : EPOCH 4 - PROGRESS: at 79.76% examples, 282182 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:02,064 : INFO : EPOCH 4 - PROGRESS: at 84.40% examples, 282558 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:03,093 : INFO : EPOCH 4 - PROGRESS: at 88.86% examples, 282623 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:04,127 : INFO : EPOCH 4 - PROGRESS: at 93.42% examples, 282660 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:05,148 : INFO : EPOCH 4 - PROGRESS: at 97.62% examples, 281948 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:15:05,589 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:15:05,608 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:15:05,610 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:15:05,626 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:15:05,628 : INFO : EPOCH - 4 : training on 9353984 raw words (6535890 effective words) took 23.1s, 282802 effective words/s
# 2020-12-22 15:15:06,680 : INFO : EPOCH 5 - PROGRESS: at 4.50% examples, 282580 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:07,733 : INFO : EPOCH 5 - PROGRESS: at 9.04% examples, 283603 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:08,775 : INFO : EPOCH 5 - PROGRESS: at 13.53% examples, 284900 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:09,812 : INFO : EPOCH 5 - PROGRESS: at 18.02% examples, 284233 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:15:10,836 : INFO : EPOCH 5 - PROGRESS: at 22.59% examples, 285960 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:11,868 : INFO : EPOCH 5 - PROGRESS: at 26.99% examples, 284364 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:12,892 : INFO : EPOCH 5 - PROGRESS: at 31.53% examples, 285898 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:15:13,922 : INFO : EPOCH 5 - PROGRESS: at 36.04% examples, 285507 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:14,924 : INFO : EPOCH 5 - PROGRESS: at 40.50% examples, 285500 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:15,954 : INFO : EPOCH 5 - PROGRESS: at 44.94% examples, 285417 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:15:16,979 : INFO : EPOCH 5 - PROGRESS: at 49.43% examples, 285456 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:17,980 : INFO : EPOCH 5 - PROGRESS: at 53.78% examples, 285449 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:19,001 : INFO : EPOCH 5 - PROGRESS: at 58.10% examples, 285032 words/s, in_qsize 8, out_qsize 3
# 2020-12-22 15:15:20,004 : INFO : EPOCH 5 - PROGRESS: at 62.70% examples, 286022 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:21,011 : INFO : EPOCH 5 - PROGRESS: at 66.96% examples, 285439 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:15:22,028 : INFO : EPOCH 5 - PROGRESS: at 71.24% examples, 284745 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:23,094 : INFO : EPOCH 5 - PROGRESS: at 75.81% examples, 284511 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:24,098 : INFO : EPOCH 5 - PROGRESS: at 80.30% examples, 284887 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:25,123 : INFO : EPOCH 5 - PROGRESS: at 84.85% examples, 284900 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:26,125 : INFO : EPOCH 5 - PROGRESS: at 89.32% examples, 285270 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:27,182 : INFO : EPOCH 5 - PROGRESS: at 93.82% examples, 284874 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:28,234 : INFO : EPOCH 5 - PROGRESS: at 98.50% examples, 284912 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:15:28,475 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:15:28,509 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:15:28,519 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:15:28,529 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:15:28,530 : INFO : EPOCH - 5 : training on 9353984 raw words (6536425 effective words) took 22.9s, 285559 effective words/s
# 2020-12-22 15:15:28,531 : INFO : training on a 46769920 raw words (32676312 effective words) took 115.0s, 284071 effective words/s
# Review 0 of 39999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:63: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Review 1000 of 39999
# Review 2000 of 39999
# Review 3000 of 39999
# Review 4000 of 39999
# Review 5000 of 39999
# Review 6000 of 39999
# Review 7000 of 39999
# Review 8000 of 39999
# Review 9000 of 39999
# Review 10000 of 39999
# Review 11000 of 39999
# Review 12000 of 39999
# Review 13000 of 39999
# Review 14000 of 39999
# Review 15000 of 39999
# Review 16000 of 39999
# Review 17000 of 39999
# Review 18000 of 39999
# Review 19000 of 39999
# Review 20000 of 39999
# Review 21000 of 39999
# Review 22000 of 39999
# Review 23000 of 39999
# Review 24000 of 39999
# Review 25000 of 39999
# Review 26000 of 39999
# Review 27000 of 39999
# Review 28000 of 39999
# Review 29000 of 39999
# Review 30000 of 39999
# Review 31000 of 39999
# Review 32000 of 39999
# Review 33000 of 39999
# Review 34000 of 39999
# Review 35000 of 39999
# Review 36000 of 39999
# Review 37000 of 39999
# Review 38000 of 39999
# Review 39000 of 39999
# Review 0 of 9999
# Review 1000 of 9999
# Review 2000 of 9999
# Review 3000 of 9999
# Review 4000 of 9999
# Review 5000 of 9999
# Review 6000 of 9999
# Review 7000 of 9999
# Review 8000 of 9999
# Review 9000 of 9999
#
# ==============================================================
# Sentiment Analysis Process ...
# ==============================================================
# 2020-12-22 15:19:01,369 : INFO : collecting all words and their counts
# 2020-12-22 15:19:01,376 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-12-22 15:19:01,426 : INFO : PROGRESS: at sentence #10000, processed 224307 words, keeping 17319 word types
# 2020-12-22 15:19:01,476 : INFO : PROGRESS: at sentence #20000, processed 434605 words, keeping 24175 word types
# 2020-12-22 15:19:01,531 : INFO : PROGRESS: at sentence #30000, processed 655533 words, keeping 29419 word types
# ==============================================================
# Hasil Test Parameter ke - 2
# Parameter  => (4, 350, 40, 10)
# Accuracy   => 0.8264826482648265
# Classification Report =>
#                precision    recall  f1-score   support
#
#     negative    0.83977   0.80629   0.82269      4992
#     positive    0.81425   0.84661   0.83012      5007
#
#     accuracy                        0.82648      9999
#    macro avg    0.82701   0.82645   0.82640      9999
# weighted avg    0.82699   0.82648   0.82641      9999
#
# ==============================================================
#
# ==============================================================
# 3.	 Parameter : (4, 400, 40, 10)
# ==============================================================
# 2020-12-22 15:19:01,590 : INFO : PROGRESS: at sentence #40000, processed 877306 words, keeping 33897 word types
# 2020-12-22 15:19:01,654 : INFO : PROGRESS: at sentence #50000, processed 1100000 words, keeping 37667 word types
# 2020-12-22 15:19:01,712 : INFO : PROGRESS: at sentence #60000, processed 1324580 words, keeping 40923 word types
# 2020-12-22 15:19:01,768 : INFO : PROGRESS: at sentence #70000, processed 1543432 words, keeping 43631 word types
# 2020-12-22 15:19:01,826 : INFO : PROGRESS: at sentence #80000, processed 1757050 words, keeping 46072 word types
# 2020-12-22 15:19:01,883 : INFO : PROGRESS: at sentence #90000, processed 1976526 words, keeping 48547 word types
# 2020-12-22 15:19:01,939 : INFO : PROGRESS: at sentence #100000, processed 2199610 words, keeping 50850 word types
# 2020-12-22 15:19:01,993 : INFO : PROGRESS: at sentence #110000, processed 2412028 words, keeping 52887 word types
# 2020-12-22 15:19:02,047 : INFO : PROGRESS: at sentence #120000, processed 2631483 words, keeping 54897 word types
# 2020-12-22 15:19:02,102 : INFO : PROGRESS: at sentence #130000, processed 2852491 words, keeping 56806 word types
# 2020-12-22 15:19:02,156 : INFO : PROGRESS: at sentence #140000, processed 3074705 words, keeping 58479 word types
# 2020-12-22 15:19:02,211 : INFO : PROGRESS: at sentence #150000, processed 3290599 words, keeping 59976 word types
# 2020-12-22 15:19:02,268 : INFO : PROGRESS: at sentence #160000, processed 3503070 words, keeping 61583 word types
# 2020-12-22 15:19:02,324 : INFO : PROGRESS: at sentence #170000, processed 3718687 words, keeping 63166 word types
# 2020-12-22 15:19:02,379 : INFO : PROGRESS: at sentence #180000, processed 3941039 words, keeping 64688 word types
# 2020-12-22 15:19:02,432 : INFO : PROGRESS: at sentence #190000, processed 4159717 words, keeping 66133 word types
# 2020-12-22 15:19:02,488 : INFO : PROGRESS: at sentence #200000, processed 4377455 words, keeping 67536 word types
# 2020-12-22 15:19:02,544 : INFO : PROGRESS: at sentence #210000, processed 4593514 words, keeping 68843 word types
# 2020-12-22 15:19:02,602 : INFO : PROGRESS: at sentence #220000, processed 4813310 words, keeping 70117 word types
# 2020-12-22 15:19:02,668 : INFO : PROGRESS: at sentence #230000, processed 5034508 words, keeping 71484 word types
# 2020-12-22 15:19:02,727 : INFO : PROGRESS: at sentence #240000, processed 5255583 words, keeping 72687 word types
# 2020-12-22 15:19:02,784 : INFO : PROGRESS: at sentence #250000, processed 5476579 words, keeping 73951 word types
# 2020-12-22 15:19:02,840 : INFO : PROGRESS: at sentence #260000, processed 5694195 words, keeping 75064 word types
# 2020-12-22 15:19:02,898 : INFO : PROGRESS: at sentence #270000, processed 5913181 words, keeping 76181 word types
# ...
# 2020-12-22 15:42:58,625 : INFO : EPOCH 2 - PROGRESS: at 6.41% examples, 207386 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:42:59,668 : INFO : EPOCH 2 - PROGRESS: at 10.20% examples, 218645 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:00,703 : INFO : EPOCH 2 - PROGRESS: at 13.95% examples, 224589 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:43:01,752 : INFO : EPOCH 2 - PROGRESS: at 17.92% examples, 228890 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:02,780 : INFO : EPOCH 2 - PROGRESS: at 21.57% examples, 229223 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:03,823 : INFO : EPOCH 2 - PROGRESS: at 25.41% examples, 230812 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:43:04,915 : INFO : EPOCH 2 - PROGRESS: at 29.43% examples, 232263 words/s, in_qsize 4, out_qsize 3
# 2020-12-22 15:43:05,927 : INFO : EPOCH 2 - PROGRESS: at 33.22% examples, 234010 words/s, in_qsize 8, out_qsize 1
# 2020-12-22 15:43:06,943 : INFO : EPOCH 2 - PROGRESS: at 37.04% examples, 234659 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:07,989 : INFO : EPOCH 2 - PROGRESS: at 40.93% examples, 235141 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:09,014 : INFO : EPOCH 2 - PROGRESS: at 44.61% examples, 235402 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:43:10,020 : INFO : EPOCH 2 - PROGRESS: at 48.51% examples, 236471 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:11,059 : INFO : EPOCH 2 - PROGRESS: at 52.21% examples, 236375 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:12,096 : INFO : EPOCH 2 - PROGRESS: at 56.00% examples, 236750 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:13,103 : INFO : EPOCH 2 - PROGRESS: at 59.82% examples, 237523 words/s, in_qsize 8, out_qsize 0
# 2020-12-22 15:43:14,154 : INFO : EPOCH 2 - PROGRESS: at 63.65% examples, 237605 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:43:15,157 : INFO : EPOCH 2 - PROGRESS: at 67.50% examples, 238273 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:16,164 : INFO : EPOCH 2 - PROGRESS: at 71.25% examples, 238506 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:17,169 : INFO : EPOCH 2 - PROGRESS: at 75.05% examples, 239056 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:18,188 : INFO : EPOCH 2 - PROGRESS: at 78.82% examples, 239056 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:43:19,218 : INFO : EPOCH 2 - PROGRESS: at 82.76% examples, 239577 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:20,232 : INFO : EPOCH 2 - PROGRESS: at 86.61% examples, 239928 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:21,258 : INFO : EPOCH 2 - PROGRESS: at 90.50% examples, 240116 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:22,260 : INFO : EPOCH 2 - PROGRESS: at 94.27% examples, 240271 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:23,313 : INFO : EPOCH 2 - PROGRESS: at 98.30% examples, 240474 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:23,656 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:43:23,678 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:43:23,709 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:43:23,715 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:43:23,717 : INFO : EPOCH - 2 : training on 9353984 raw words (6536328 effective words) took 27.1s, 241074 effective words/s
# 2020-12-22 15:43:24,733 : INFO : EPOCH 3 - PROGRESS: at 3.52% examples, 229388 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:25,766 : INFO : EPOCH 3 - PROGRESS: at 7.36% examples, 236370 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:43:26,780 : INFO : EPOCH 3 - PROGRESS: at 11.15% examples, 240047 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:27,784 : INFO : EPOCH 3 - PROGRESS: at 14.66% examples, 239023 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:28,812 : INFO : EPOCH 3 - PROGRESS: at 18.68% examples, 241509 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:29,819 : INFO : EPOCH 3 - PROGRESS: at 22.49% examples, 242783 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:30,827 : INFO : EPOCH 3 - PROGRESS: at 26.24% examples, 242600 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:43:31,884 : INFO : EPOCH 3 - PROGRESS: at 30.15% examples, 242770 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:43:32,896 : INFO : EPOCH 3 - PROGRESS: at 33.97% examples, 243386 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:33,966 : INFO : EPOCH 3 - PROGRESS: at 38.02% examples, 243158 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:43:34,986 : INFO : EPOCH 3 - PROGRESS: at 41.95% examples, 244104 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:36,055 : INFO : EPOCH 3 - PROGRESS: at 45.92% examples, 243852 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:37,055 : INFO : EPOCH 3 - PROGRESS: at 49.86% examples, 244916 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:38,079 : INFO : EPOCH 3 - PROGRESS: at 53.57% examples, 244420 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:39,115 : INFO : EPOCH 3 - PROGRESS: at 57.17% examples, 243364 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:43:40,146 : INFO : EPOCH 3 - PROGRESS: at 61.11% examples, 243793 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:41,147 : INFO : EPOCH 3 - PROGRESS: at 64.88% examples, 244210 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:43:42,161 : INFO : EPOCH 3 - PROGRESS: at 68.67% examples, 243999 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:43:43,251 : INFO : EPOCH 3 - PROGRESS: at 72.74% examples, 243973 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:44,302 : INFO : EPOCH 3 - PROGRESS: at 76.66% examples, 244188 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:43:45,293 : INFO : EPOCH 3 - PROGRESS: at 80.29% examples, 243809 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:46,327 : INFO : EPOCH 3 - PROGRESS: at 84.29% examples, 244158 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:43:47,340 : INFO : EPOCH 3 - PROGRESS: at 88.12% examples, 244182 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:48,352 : INFO : EPOCH 3 - PROGRESS: at 91.92% examples, 244069 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:49,381 : INFO : EPOCH 3 - PROGRESS: at 95.88% examples, 244354 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:50,380 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:43:50,398 : INFO : EPOCH 3 - PROGRESS: at 99.80% examples, 244516 words/s, in_qsize 2, out_qsize 1
# 2020-12-22 15:43:50,399 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:43:50,407 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:43:50,417 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:43:50,418 : INFO : EPOCH - 3 : training on 9353984 raw words (6534682 effective words) took 26.7s, 244852 effective words/s
# 2020-12-22 15:43:51,448 : INFO : EPOCH 4 - PROGRESS: at 3.63% examples, 233722 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:52,472 : INFO : EPOCH 4 - PROGRESS: at 7.23% examples, 232766 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:53,493 : INFO : EPOCH 4 - PROGRESS: at 10.85% examples, 232377 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:54,540 : INFO : EPOCH 4 - PROGRESS: at 14.55% examples, 234234 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:55,559 : INFO : EPOCH 4 - PROGRESS: at 18.57% examples, 238008 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:56,599 : INFO : EPOCH 4 - PROGRESS: at 22.39% examples, 238548 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:57,633 : INFO : EPOCH 4 - PROGRESS: at 26.25% examples, 239029 words/s, in_qsize 8, out_qsize 1
# 2020-12-22 15:43:58,678 : INFO : EPOCH 4 - PROGRESS: at 30.06% examples, 239138 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:43:59,702 : INFO : EPOCH 4 - PROGRESS: at 33.76% examples, 239180 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:44:00,753 : INFO : EPOCH 4 - PROGRESS: at 37.68% examples, 239114 words/s, in_qsize 5, out_qsize 2
# 2020-12-22 15:44:01,772 : INFO : EPOCH 4 - PROGRESS: at 41.55% examples, 239800 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:44:02,776 : INFO : EPOCH 4 - PROGRESS: at 45.39% examples, 240618 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:03,792 : INFO : EPOCH 4 - PROGRESS: at 49.02% examples, 240074 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:44:04,799 : INFO : EPOCH 4 - PROGRESS: at 52.94% examples, 241214 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:05,839 : INFO : EPOCH 4 - PROGRESS: at 56.75% examples, 241233 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:44:06,847 : INFO : EPOCH 4 - PROGRESS: at 60.45% examples, 241295 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:07,850 : INFO : EPOCH 4 - PROGRESS: at 64.26% examples, 241810 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:44:08,860 : INFO : EPOCH 4 - PROGRESS: at 68.05% examples, 241791 words/s, in_qsize 8, out_qsize 0
# 2020-12-22 15:44:09,874 : INFO : EPOCH 4 - PROGRESS: at 71.87% examples, 242085 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:10,896 : INFO : EPOCH 4 - PROGRESS: at 75.70% examples, 242256 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:11,902 : INFO : EPOCH 4 - PROGRESS: at 79.45% examples, 242247 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:12,966 : INFO : EPOCH 4 - PROGRESS: at 83.08% examples, 241327 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:44:13,992 : INFO : EPOCH 4 - PROGRESS: at 86.95% examples, 241448 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:44:15,005 : INFO : EPOCH 4 - PROGRESS: at 90.83% examples, 241710 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:16,027 : INFO : EPOCH 4 - PROGRESS: at 94.70% examples, 241891 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:17,028 : INFO : EPOCH 4 - PROGRESS: at 98.71% examples, 242500 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:17,327 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:44:17,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:44:17,381 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:44:17,382 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:44:17,388 : INFO : EPOCH - 4 : training on 9353984 raw words (6534626 effective words) took 27.0s, 242425 effective words/s
# 2020-12-22 15:44:18,403 : INFO : EPOCH 5 - PROGRESS: at 3.52% examples, 230405 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:19,437 : INFO : EPOCH 5 - PROGRESS: at 7.46% examples, 240373 words/s, in_qsize 8, out_qsize 0
# 2020-12-22 15:44:20,519 : INFO : EPOCH 5 - PROGRESS: at 11.37% examples, 239519 words/s, in_qsize 6, out_qsize 1
# 2020-12-22 15:44:21,539 : INFO : EPOCH 5 - PROGRESS: at 15.19% examples, 242881 words/s, in_qsize 8, out_qsize 0
# 2020-12-22 15:44:22,550 : INFO : EPOCH 5 - PROGRESS: at 19.01% examples, 242526 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 15:44:23,573 : INFO : EPOCH 5 - PROGRESS: at 22.90% examples, 244141 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:24,589 : INFO : EPOCH 5 - PROGRESS: at 26.67% examples, 243461 words/s, in_qsize 4, out_qsize 3
# 2020-12-22 15:44:25,624 : INFO : EPOCH 5 - PROGRESS: at 30.60% examples, 244227 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:26,642 : INFO : EPOCH 5 - PROGRESS: at 34.42% examples, 244497 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:27,663 : INFO : EPOCH 5 - PROGRESS: at 38.45% examples, 245339 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:28,673 : INFO : EPOCH 5 - PROGRESS: at 42.06% examples, 244374 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:29,715 : INFO : EPOCH 5 - PROGRESS: at 46.03% examples, 244651 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:30,739 : INFO : EPOCH 5 - PROGRESS: at 49.65% examples, 243676 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:31,749 : INFO : EPOCH 5 - PROGRESS: at 53.46% examples, 243973 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:32,763 : INFO : EPOCH 5 - PROGRESS: at 57.17% examples, 243765 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:33,780 : INFO : EPOCH 5 - PROGRESS: at 60.68% examples, 242670 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:34,801 : INFO : EPOCH 5 - PROGRESS: at 64.37% examples, 242477 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:35,859 : INFO : EPOCH 5 - PROGRESS: at 68.47% examples, 242901 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:36,896 : INFO : EPOCH 5 - PROGRESS: at 72.31% examples, 242860 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:37,907 : INFO : EPOCH 5 - PROGRESS: at 76.00% examples, 242799 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:39,007 : INFO : EPOCH 5 - PROGRESS: at 80.08% examples, 242683 words/s, in_qsize 8, out_qsize 1
# 2020-12-22 15:44:40,019 : INFO : EPOCH 5 - PROGRESS: at 84.06% examples, 243223 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:41,026 : INFO : EPOCH 5 - PROGRESS: at 87.80% examples, 243150 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:42,031 : INFO : EPOCH 5 - PROGRESS: at 91.59% examples, 243149 words/s, in_qsize 8, out_qsize 2
# 2020-12-22 15:44:43,034 : INFO : EPOCH 5 - PROGRESS: at 95.45% examples, 243456 words/s, in_qsize 7, out_qsize 0
# 2020-12-22 15:44:44,108 : INFO : EPOCH 5 - PROGRESS: at 99.36% examples, 243111 words/s, in_qsize 7, out_qsize 2
# 2020-12-22 15:44:44,146 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 15:44:44,196 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 15:44:44,205 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 15:44:44,216 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 15:44:44,218 : INFO : EPOCH - 5 : training on 9353984 raw words (6535220 effective words) took 26.8s, 243716 effective words/s
# 2020-12-22 15:44:44,219 : INFO : training on a 46769920 raw words (32674909 effective words) took 134.8s, 242442 effective words/s
# Review 0 of 39999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:63: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Review 1000 of 39999
# Review 2000 of 39999
# Review 3000 of 39999
# Review 4000 of 39999
# Review 5000 of 39999
# Review 6000 of 39999
# Review 7000 of 39999
# Review 8000 of 39999
# Review 9000 of 39999
# Review 10000 of 39999
# Review 11000 of 39999
# Review 12000 of 39999
# Review 13000 of 39999
# Review 14000 of 39999
# Review 15000 of 39999
# Review 16000 of 39999
# Review 17000 of 39999
# Review 18000 of 39999
# Review 19000 of 39999
# Review 20000 of 39999
# Review 21000 of 39999
# Review 22000 of 39999
# Review 23000 of 39999
# Review 24000 of 39999
# Review 25000 of 39999
# Review 26000 of 39999
# Review 27000 of 39999
# Review 28000 of 39999
# Review 29000 of 39999
# Review 30000 of 39999
# Review 31000 of 39999
# Review 32000 of 39999
# Review 33000 of 39999
# Review 34000 of 39999
# Review 35000 of 39999
# Review 36000 of 39999
# Review 37000 of 39999
# Review 38000 of 39999
# Review 39000 of 39999
# Review 0 of 9999
# Review 1000 of 9999
# Review 2000 of 9999
# Review 3000 of 9999
# Review 4000 of 9999
# Review 5000 of 9999
# Review 6000 of 9999
# Review 7000 of 9999
# Review 8000 of 9999
# Review 9000 of 9999
#
# ==============================================================
# Sentiment Analysis Process ...
# ==============================================================
#
# ==============================================================
# Hasil Test Parameter ke - 7
# Parameter  => (4, 600, 40, 10)
# Accuracy   => 0.8323832383238324
# Classification Report =>
#                precision    recall  f1-score   support
#
#     negative    0.84730   0.81030   0.82838      4992
#     positive    0.81876   0.85440   0.83620      5007
#
#     accuracy                        0.83238      9999
#    macro avg    0.83303   0.83235   0.83229      9999
# weighted avg    0.83301   0.83238   0.83230      9999
#
# ==============================================================
#
# ==============================================================
# Best Parameter  => (4, 600, 40, 10)
# Accuracy   => 0.8323832383238324
# ==============================================================

# %%
print(best_score)
print(best_parameter)
# Out:
# [0.8283828382838284, 0.8264826482648265, 0.8294829482948295, 0.831983198319832, 0.8310831083108311, 0.832083208320832, 0.8323832383238324]
# [(4, 300, 40, 10), (4, 350, 40, 10), (4, 400, 40, 10), (4, 450, 40, 10), (4, 500, 40, 10), (4, 550, 40, 10), (4, 600, 40, 10)]
